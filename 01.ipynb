# %%
# Cài đặt
# !pip install Pillow
# !conda install Pillow

# %%
# Import lớp Image
from PIL import Image

# %%
#thư mục chứa hình ảnh 
dir = 'C:/Users/ADMIN/Downloads/img/1.jpg'

# %%
# Đường dẫn đến hình ảnh
image_path = dir
print(image_path)
# Out:
# C:/Users/ADMIN/Downloads/img/1.jpg

# %%
img1= Image.open(image_path)

# %%
# Hiển thị hình ảnh
display(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
# In một số thông tin
# In định dạng ảnh
print("Định dang ảnh: ", img1.format)
# Out:
# Định dang ảnh:  JPEG

# %%
# In ra size
print("Kích thước hình ảnh: ", img1.size)
# Out:
# Kích thước hình ảnh:  (500, 375)
